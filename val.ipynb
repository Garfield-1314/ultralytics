# %%
from ultralytics import YOLO

# Load a model
model = YOLO("runs/detect/train/weights/best.pt")

# Customize validation settings
validation_results = model.val(data="data.yaml", imgsz=640, batch=16, conf=0.25, iou=0.6, device="0")
# Out:
# Ultralytics 8.3.75  Python-3.11.11 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 2060 with Max-Q Design, 6144MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# val: Scanning E:\github\yolo\datasets\coco8\labels\val.cache... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.98s/it]
#                    all          4         17      0.786       0.65      0.722      0.525
#                 person          3         10      0.718        0.4      0.598      0.372
#                    dog          1          1          1          1      0.995      0.796
#                  horse          1          2          1          1      0.995       0.71
#               elephant          1          2          1        0.5       0.75      0.375
#               umbrella          1          1          1          1      0.995      0.895
#           potted plant          1          1          0          0          0          0
# Speed: 3.1ms preprocess, 73.3ms inference, 0.0ms loss, 3.2ms postprocess per image
# Results saved to e:\github\yolo\ultralytics\runs\detect\val2
