# %%
from ultralytics import YOLO

if __name__ == '__main__':
    # 创建新模型或加载预训练模型
    model = YOLO("yolo11n.pt")
    # 训练模型，禁用 AMP
    results = model.train(data="data.yaml", epochs=20, batch=-1)
# Out:
# Ultralytics 8.3.75  Python-3.11.11 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 2060 with Max-Q Design, 6144MiB)
# ...
